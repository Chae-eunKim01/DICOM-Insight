# %%
from PIL import Image

img=Image.open(r"C:\Users\rlaco\Desktop\DICOM_Viewer\assets\Logo.png")

img.save(
    r"C:\Users\rlaco\Desktop\DICOM_Viewer\assets\DICOM_Insight.ico",
    format="ICO",
    sizes=[(16,16),(32,32),(48,48),(64,64),(128,128),(256,256)]
)
